# %% [markdown]
# <a href="https://colab.research.google.com/github/Hakim-Singh-ux/fcc-data-analysis-python/blob/main/mean_var_std.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import numpy as np

def calculate(lst):
    if len(lst) != 9:
        raise ValueError("List must contain nine numbers.")

    a = np.array(lst).reshape(3, 3)

    return {
        "mean":               [a.mean(axis=0).tolist(), a.mean(axis=1).tolist(), float(a.mean())],
        "variance":           [a.var(axis=0).tolist(),  a.var(axis=1).tolist(),  float(a.var())],
        "standard deviation": [a.std(axis=0).tolist(),  a.std(axis=1).tolist(),  float(a.std())],
        "max":                [a.max(axis=0).tolist(),  a.max(axis=1).tolist(),  float(a.max())],
        "min":                [a.min(axis=0).tolist(),  a.min(axis=1).tolist(),  float(a.min())],
        "sum":                [a.sum(axis=0).tolist(),  a.sum(axis=1).tolist(),  float(a.sum())]
    }
print(calculate(eval(input())))
# Out:
# [0,1,2,3,4,5,6,7,8]
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0], 'variance': [[6.0, 6.0, 6.0], [0.6666666666666666, 0.6666666666666666, 0.6666666666666666], 6.666666666666667], 'standard deviation': [[2.449489742783178, 2.449489742783178, 2.449489742783178], [0.816496580927726, 0.816496580927726, 0.816496580927726], 2.581988897471611], 'max': [[6, 7, 8], [2, 5, 8], 8.0], 'min': [[0, 1, 2], [0, 3, 6], 0.0], 'sum': [[9, 12, 15], [3, 12, 21], 36.0]}
